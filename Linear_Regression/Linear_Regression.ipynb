# %%
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
db_data = datasets.load_diabetes()
db_data
x = db_data.data
y = db_data.target
x_train,x_test,y_train,y_test = model_selection.train_test_split(x,y)
df = pd.DataFrame(x,columns=db_data.feature_names)
df1 = pd.DataFrame(x_train)
aglo = LinearRegression()
aglo.fit(x_train,y_train)
y_pred = aglo.predict(x_test)
plt.scatter(y_pred,y_test)
plt.title("Testing Linear regression outputs")
plt.axis([0,250,0,250])
plt.xlabel("prediction")
plt.ylabel("Actual")
plt.show()
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df1
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.081798  0.050680  0.042296 -0.019442  0.039710  0.057558 -0.069172
# 1   -0.009147 -0.044642  0.037984 -0.040099 -0.024960 -0.003819 -0.043401
# 2    0.001751  0.050680  0.059541 -0.002228  0.061725  0.063195 -0.058127
# 3    0.045341  0.050680 -0.002973  0.107944  0.035582  0.022485  0.026550
# 4   -0.107226 -0.044642 -0.011595 -0.040099  0.049341  0.064447 -0.013948
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.019913  0.050680  0.014272  0.063187  0.014942  0.020293 -0.047082
# 327 -0.063635 -0.044642  0.035829 -0.022885 -0.030464 -0.018850 -0.006584
# 328  0.063504  0.050680  0.088642  0.070072  0.020446  0.037517 -0.050764
# 329 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 330 -0.009147 -0.044642 -0.015906  0.070072  0.012191  0.022172  0.015505
#
#             7         8         9
# 0    0.108111  0.047190 -0.038357
# ...
